# %% [markdown]
# # California Housing Regression Model Building
#
# This demo shows how you can use SageMaker Studio Notebooks to build machine learning models. We'll cover jupyter extensions, local model building, scaled SageMaker training jobs, Hyperparameter optimnization, and model deployment.
#
# Now we will demonstrate these capabilities through a `California Housing` regression example. The experiment will be organized as follows:
#
# Make sure you selected `Python 3 (TensorFlow 2.3 Python 3.7 CPU Optimized)` kernel.

# %% [markdown]
# ### Setup

# %%
# Installed Libraries
import itertools
import os
import time

import boto3
import numpy as np
import pandas as pd
import sagemaker

# Project Imports
from california_housing_tf2 import get_model, train_model
from sagemaker import get_execution_role
from sagemaker.tensorflow import TensorFlow
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Download California Housing dataset

# %%
data_dir = os.path.join(os.getcwd(), "data")
os.makedirs(data_dir, exist_ok=True)

train_dir = os.path.join(os.getcwd(), "data/train")
os.makedirs(train_dir, exist_ok=True)

test_dir = os.path.join(os.getcwd(), "data/test")
os.makedirs(test_dir, exist_ok=True)

data_set = fetch_california_housing(as_frame=True)

# %%
data_set.frame.head()

# %% [markdown]
# #### Objective
# The target contains the median of the house value for each district. Therefore, this problem is a regression problem.

# %%
print(data_set.target)

# %% [markdown]
# ### Install Plotting Libraries

# %%
# %pip install -q plotly nbformat matplotlib

# %% [markdown]
# ### Visualize Data with Matplotlib

# %%
import matplotlib.pyplot as plt

data_set.frame.hist(figsize=(12, 10), bins=15, edgecolor="black")
plt.subplots_adjust(hspace=0.7, wspace=0.4)

# %% [markdown]
# ### Interactively Visualize Data with Plotly

# %%
import plotly.express as px

fig = px.histogram(data_set.frame["HouseAge"], x="HouseAge", nbins=15)
fig.show()

# %% [markdown]
# ### Data Transformations

# %%
X = pd.DataFrame(data_set.data, columns=data_set.feature_names)
Y = pd.DataFrame(data_set.target)

# We partition the dataset into 2/3 training and 1/3 test set.
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.33)

scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

np.save(os.path.join(train_dir, "x_train.npy"), x_train)
np.save(os.path.join(test_dir, "x_test.npy"), x_test)
np.save(os.path.join(train_dir, "y_train.npy"), y_train)
np.save(os.path.join(test_dir, "y_test.npy"), y_test)

# %% [markdown]
# ## Build Model Locally

# %%
my_model = get_model()
print(my_model.summary())

# %%
learning_rate = 0.1
epochs = 20
batch_size = 64
train_model(
    model=my_model,
    learning_rate=learning_rate,
    epochs=epochs,
    batch_size=batch_size,
    x_train=x_train,
    y_train=y_train,
    x_test=x_test,
    y_test=y_test,
    output_dir=os.getcwd(),
)

# %% [markdown]
# ## Use SageMaker Training Jobs for Scaled Training

# %%
sess = boto3.Session()
sm = sess.client("sagemaker")
role = get_execution_role()
sagemaker_session = sagemaker.Session(boto_session=sess)
bucket = sagemaker_session.default_bucket()
prefix = "tf2-california-housing-experiment"

# %% [markdown]
# ### Upload Data to S3

# %%
s3_inputs_train = sagemaker.Session().upload_data(
    path="data/train", bucket=bucket, key_prefix=prefix + "/train"
)
s3_inputs_test = sagemaker.Session().upload_data(
    path="data/test", bucket=bucket, key_prefix=prefix + "/test"
)
inputs = {"train": s3_inputs_train, "test": s3_inputs_test}
print(inputs)

# %% [markdown]
# ### Step 1 - Set up the Experiment
#
# Create an experiment to track all the model training iterations. Experiments are a great way to organize your data science work. You can create experiments to organize all your model development work for : [1] a business use case you are addressing (e.g. create experiment named “customer churn prediction”), or [2] a data science team that owns the experiment (e.g. create experiment named “marketing analytics experiment”), or [3] a specific data science and ML project. Think of it as a “folder” for organizing your “files”.

# %% [markdown]
# ### Create an Experiment

# %%
from smexperiments.experiment import Experiment
from smexperiments.tracker import Tracker
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent

# %%
california_housing_experiment = Experiment.create(
    experiment_name=f"tf2-california-housing-{int(time.time())}",
    description="Training on california housing dataset",
    sagemaker_boto_client=sm,
)
print(california_housing_experiment)

# %% [markdown]
# ### Step 2 - Track Experiment
# ### Now create a Trial for each training run to track its inputs, parameters, and metrics.
# While training the ResNet-50 CNN model on SageMaker, you will experiment with several values for the number of hidden channel in the model. You will create a Trial to track each training job run. You will also create a `TrialComponent` from the tracker we created before, and add to the Trial. This will enrich the Trial with the parameters we captured from the data pre-processing stage.

# %%
hyperparam_options = {"learning_rate": [0.1], "epochs": [10]}

hypnames, hypvalues = zip(*hyperparam_options.items())
trial_hyperparameter_set = [
    dict(zip(hypnames, h)) for h in itertools.product(*hypvalues)
]
trial_hyperparameter_set

# %% [markdown]
# If you want to run the following training jobs asynchronously, you may need to increase your resource limit. Otherwise, you can run them sequentially.

# %%
from sagemaker.tensorflow import TensorFlow

run_number = 1
for trial_hyp in trial_hyperparameter_set:
    # Combine static hyperparameters and trial specific hyperparameters
    hyperparams = trial_hyp

    # Create unique job name with hyperparameter and time
    time_append = int(time.time())
    hyp_append = "-".join([str(elm).replace(".", "-") for elm in trial_hyp.values()])
    training_job_name = f"tf2-california-housing-training-{hyp_append}-{time_append}"
    trial_name = f"trial-tf2-california-housing-training-{hyp_append}-{time_append}"
    trial_desc = f"my-tensorflow2-california-housing-run-{run_number}"

    # Create a new Trial and associate Tracker to it
    tf2_california_housing_trial = Trial.create(
        trial_name=trial_name,
        experiment_name=california_housing_experiment.experiment_name,
        sagemaker_boto_client=sm,
        tags=[{"Key": "trial-desc", "Value": trial_desc}],
    )

    # Create an experiment config that associates training job to the Trial
    experiment_config = {
        "ExperimentName": california_housing_experiment.experiment_name,
        "TrialName": tf2_california_housing_trial.trial_name,
        "TrialComponentDisplayName": training_job_name,
    }

    metric_definitions = [
        {"Name": "loss", "Regex": "loss: ([0-9\\.]+)"},
        {"Name": "accuracy", "Regex": "accuracy: ([0-9\\.]+)"},
        {"Name": "val_loss", "Regex": "val_loss: ([0-9\\.]+)"},
        {"Name": "val_accuracy", "Regex": "val_accuracy: ([0-9\\.]+)"},
    ]

    # Create a TensorFlow Estimator with the Trial specific hyperparameters
    tf2_california_housing_estimator = TensorFlow(
        entry_point="california_housing_tf2.py",
        role=sagemaker.get_execution_role(),
        instance_count=1,
        instance_type="ml.m5.large",
        framework_version="2.4.1",
        hyperparameters=hyperparams,
        py_version="py37",
        metric_definitions=metric_definitions,
        enable_sagemaker_metrics=True,
        tags=[{"Key": "trial-desc", "Value": trial_desc}],
    )

    # Launch a training job
    tf2_california_housing_estimator.fit(
        inputs,
        job_name=training_job_name,
        experiment_config=experiment_config,
        wait=False,
    )

    # give it a while before dispatching the next training job
    time.sleep(2)
    run_number = run_number + 1

# %% [markdown]
# ### Compare the model training runs for an experiment
#
# Now you will use the analytics capabilities of Python SDK to query and compare the training runs for identifying the best model produced by our experiment. You can retrieve trial components by using a search expression.

# %%
from sagemaker.analytics import ExperimentAnalytics

experiment_name = california_housing_experiment.experiment_name

trial_component_analytics = ExperimentAnalytics(
    sagemaker_session=sagemaker_session, experiment_name=experiment_name
)
trial_comp_ds_jobs = trial_component_analytics.dataframe()
trial_comp_ds_jobs
# Out:
#                                   TrialComponentName  \
# 0  tf2-california-housing-training-0-1-10-1660948...
# 1  tf2-california-housing-training-0-1-100-166094...
# 2  tf2-california-housing-training-0-5-100-166094...
# 3  tf2-california-housing-training-0-3-100-166094...
#
#                                          DisplayName  \
# 0  tf2-california-housing-training-0-1-10-1660948520
# 1  tf2-california-housing-training-0-1-100-166094...
# 2  tf2-california-housing-training-0-5-100-166094...
# 3  tf2-california-housing-training-0-3-100-166094...
#
#                                            SourceArn  \
# 0  arn:aws:sagemaker:us-east-1:695215524818:train...
# 1  arn:aws:sagemaker:us-east-1:695215524818:train...
# 2  arn:aws:sagemaker:us-east-1:695215524818:train...
# 3  arn:aws:sagemaker:us-east-1:695215524818:train...
#
#                                   SageMaker.ImageUri  SageMaker.InstanceCount  \
# 0  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
# 1  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
# 2  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
# 3  763104351884.dkr.ecr.us-east-1.amazonaws.com/t...                      1.0
#
#   SageMaker.InstanceType  SageMaker.VolumeSizeInGB  epochs  learning_rate  \
# 0            ml.m5.large                      30.0    10.0            0.1
# 1            ml.m5.large                      30.0   100.0            0.1
# 2            ml.m5.large                      30.0   100.0            0.5
# 3            ml.m5.large                      30.0   100.0            0.3
#
#                                            model_dir  ...  test - MediaType  \
# 0  "s3://sagemaker-us-east-1-695215524818/tf2-cal...  ...              None
# 1  "s3://sagemaker-us-east-1-695215524818/tf2-cal...  ...              None
# 2  "s3://sagemaker-us-east-1-695215524818/tf2-cal...  ...              None
# 3  "s3://sagemaker-us-east-1-695215524818/tf2-cal...  ...              None
#
#                                         test - Value train - MediaType  \
# 0  s3://sagemaker-us-east-1-695215524818/tf2-cali...              None
# 1  s3://sagemaker-us-east-1-695215524818/tf2-cali...              None
# 2  s3://sagemaker-us-east-1-695215524818/tf2-cali...              None
# 3  s3://sagemaker-us-east-1-695215524818/tf2-cali...              None
#
#                                        train - Value  \
# 0  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 1  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 2  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 3  s3://sagemaker-us-east-1-695215524818/tf2-cali...
#
#   SageMaker.DebugHookOutput - MediaType  \
# 0                                  None
# 1                                  None
# 2                                  None
# 3                                  None
#
#         SageMaker.DebugHookOutput - Value  \
# 0  s3://sagemaker-us-east-1-695215524818/
# 1  s3://sagemaker-us-east-1-695215524818/
# 2  s3://sagemaker-us-east-1-695215524818/
# 3  s3://sagemaker-us-east-1-695215524818/
#
#    SageMaker.ModelArtifact - MediaType  \
# 0                                 None
# 1                                 None
# 2                                 None
# 3                                 None
#
#                      SageMaker.ModelArtifact - Value  \
# 0  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 1  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 2  s3://sagemaker-us-east-1-695215524818/tf2-cali...
# 3  s3://sagemaker-us-east-1-695215524818/tf2-cali...
#
#                                               Trials  \
# 0  [trial-tf2-california-housing-training-0-1-10-...
# 1  [trial-tf2-california-housing-training-0-1-100...
# 2  [trial-tf2-california-housing-training-0-5-100...
# 3  [trial-tf2-california-housing-training-0-3-100...
#
#                            Experiments
# 0  [tf2-california-housing-1660948083]
# 1  [tf2-california-housing-1660948083]
# 2  [tf2-california-housing-1660948083]
# 3  [tf2-california-housing-1660948083]
#
# [4 rows x 67 columns]

# %% [markdown]
# Let's show the accuracy, epochs and optimizer.
# You will sort the results by accuracy descending.

# %%
trial_comp_ds_jobs = trial_comp_ds_jobs.sort_values("val_loss - Last", ascending=False)
trial_comp_ds_jobs[["TrialComponentName", "val_loss - Last", "epochs", "learning_rate"]]
# Out:
#                                   TrialComponentName  val_loss - Last  epochs  \
# 2  tf2-california-housing-training-0-5-100-166094...           1.6596   100.0
# 0  tf2-california-housing-training-0-1-10-1660948...           0.9007    10.0
# 1  tf2-california-housing-training-0-1-100-166094...           0.4076   100.0
# 3  tf2-california-housing-training-0-3-100-166094...           0.3212   100.0
#
#    learning_rate
# 2            0.5
# 0            0.1
# 1            0.1
# 3            0.3

# %% [markdown]
# ### Compare Experiments, Trials, and Trial Components in Amazon SageMaker Studio
#
# You can compare experiments, trials, and trial components by selecting the entities and opening them in the trial components list. The trial components list is referred to as the Studio Leaderboard. In the Leaderboard you can do the following:
# - View detailed information about the entities
# - Compare entities
# - Stop a training job
# - Deploy a model
#
# <b>To compare experiments, trials, and trial components</b>
# - In the left sidebar of SageMaker Studio, choose the <b>SageMaker Experiment List icon</b>.
# - In the <b>Experiments</b> browser, choose either the experiment or trial list.
# - Choose the experiments or trials that you want to compare, right-click the selection, and then choose <b>Open in trial component list</b>. The Leaderboard opens and lists the associated Experiments entities as shown in the following screenshot.
#
# ![studio_trial_component_list](./images/studio_trial_component_list.png)

# %% [markdown]
# ## Use Hyperparamter Tuning

# %%
from sagemaker.tuner import ContinuousParameter, HyperparameterTuner

objective_metric_name = "loss"
objective_type = "Minimize"
metric_definitions = [
    {"Name": "loss", "Regex": "loss: ([0-9\\.]+)"},
    {"Name": "accuracy", "Regex": "accuracy: ([0-9\\.]+)"},
    {"Name": "val_loss", "Regex": "val_loss: ([0-9\\.]+)"},
    {"Name": "val_accuracy", "Regex": "val_accuracy: ([0-9\\.]+)"},
]

hyperparamter_range = {"learning_rate": ContinuousParameter(1e-4, 1e-3)}

tf2_california_housing_estimator = TensorFlow(
    entry_point="california_housing_tf2.py",
    role=sagemaker.get_execution_role(),
    instance_count=1,
    instance_type="ml.m5.large",
    framework_version="2.4.1",
    py_version="py37",
)

tuner = HyperparameterTuner(
    tf2_california_housing_estimator,
    objective_metric_name,
    hyperparamter_range,
    metric_definitions,
    base_tuning_job_name="housing-hpo",
    strategy="Bayesian",
    max_jobs=6,
    max_parallel_jobs=3,
    objective_type=objective_type,
)

tuner.fit(inputs)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating hyperparameter tuning job with name: housing-hpo-220819-2300
# .........................................................................!

# %%
# results = tuner.
results = tuner.analytics()
results.training_job_summaries()
# Out:
# [{'TrainingJobName': 'housing-hpo-220819-2300-006-a7725166',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-006-a7725166',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 5, 29, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 5, 37, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 6, 44, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.000357461560222102'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 3.32069993019104},
#   'ObjectiveStatus': 'Succeeded'},
#  {'TrainingJobName': 'housing-hpo-220819-2300-005-20668f66',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-005-20668f66',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 4, 41, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 5, 38, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 6, 40, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.00013074957172550544'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 6.253399848937988},
#   'ObjectiveStatus': 'Succeeded'},
#  {'TrainingJobName': 'housing-hpo-220819-2300-004-0e57a9ac',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-004-0e57a9ac',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 4, 24, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 4, 32, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 5, 34, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.0002654431276990722'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 5.388999938964844},
#   'ObjectiveStatus': 'Succeeded'},
#  {'TrainingJobName': 'housing-hpo-220819-2300-003-5d2dad24',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-003-5d2dad24',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 0, 49, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 2, 22, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 4, 9, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.0007208346233858244'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 4.61329984664917},
#   'ObjectiveStatus': 'Succeeded'},
#  {'TrainingJobName': 'housing-hpo-220819-2300-002-aee97a54',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-002-aee97a54',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 0, 48, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 2, 24, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 4, 35, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.0007165733326464082'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 3.3531999588012695},
#   'ObjectiveStatus': 'Succeeded'},
#  {'TrainingJobName': 'housing-hpo-220819-2300-001-2e0e9534',
#   'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:695215524818:training-job/housing-hpo-220819-2300-001-2e0e9534',
#   'CreationTime': datetime.datetime(2022, 8, 19, 23, 0, 46, tzinfo=tzlocal()),
#   'TrainingStartTime': datetime.datetime(2022, 8, 19, 23, 2, 31, tzinfo=tzlocal()),
#   'TrainingEndTime': datetime.datetime(2022, 8, 19, 23, 5, 18, tzinfo=tzlocal()),
#   'TrainingJobStatus': 'Completed',
#   'TunedHyperParameters': {'learning_rate': '0.0003657968702091628'},
#   'FinalHyperParameterTuningJobObjectiveMetric': {'MetricName': 'loss',
#    'Value': 2.4370999336242676},
#   'ObjectiveStatus': 'Succeeded'}]

# %% [markdown]
# ### Deploy Best Model

# %%
predictor = tuner.deploy(initial_instance_count=1, instance_type="ml.m5.xlarge")
# Out:
# 2022-08-19 23:05:32 Starting - Preparing the instances for training
# 2022-08-19 23:05:32 Downloading - Downloading input data
# 2022-08-19 23:05:32 Training - Training image download completed. Training in progress.
# 2022-08-19 23:05:32 Uploading - Uploading generated training model
# 2022-08-19 23:05:32 Completed - Resource reused by training job: housing-hpo-220819-2300-006-a7725166
# WARNING:sagemaker.deprecations:update_endpoint is a no-op in sagemaker>=2.
# See: https://sagemaker.readthedocs.io/en/stable/v2.html for details.
# INFO:sagemaker:Creating model with name: housing-hpo-2022-08-19-23-19-12-488
# INFO:sagemaker:Creating endpoint with name housing-hpo-220819-2300-001-2e0e9534
# -----!

# %%
predictions = predictor.predict(x_test[:10])
print(predictions)
# Out:
# {'predictions': [[0.868044078], [1.03509223], [0.762453794], [0.842506826], [0.873786747], [1.30575609], [1.29384637], [0.879887], [1.28810823], [1.2965852]]}

# %%
predictor.delete_endpoint()
